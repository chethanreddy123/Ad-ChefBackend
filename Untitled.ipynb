# %%
from pymongo.mongo_client import MongoClient

ConnectData = MongoClient("mongodb://aioverflow:1234@ac-pu6wews-shard-00-00.me4dkct.mongodb.net:27017,ac-pu6wews-shard-00-01.me4dkct.mongodb.net:27017,ac-pu6wews-shard-00-02.me4dkct.mongodb.net:27017/?ssl=true&replicaSet=atlas-jcoztp-shard-0&authSource=admin&retryWrites=true&w=majority")
UserData = ConnectData.Ad_Chef.userData

# %%
UserData
# Out:
# Collection(Database(MongoClient(host=['ac-pu6wews-shard-00-02.me4dkct.mongodb.net:27017', 'ac-pu6wews-shard-00-00.me4dkct.mongodb.net:27017', 'ac-pu6wews-shard-00-01.me4dkct.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-jcoztp-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'Ad_Chef'), 'userData')

# %%
Data = {
        "User_Id" : 122423,
        "Email_Id" : "achethanreddy1921@gmail.com",
        "Name" : "Chethan",
        "TypeOfSub" : None,
        "No_Tokens" : None,
        "Fov_Ads" : [],
        "Ads_List" : []
}

# %%
UserData.insert_one(Data)

# %%
UserData.delete_many({})

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np

# Generate some random data for the model
x_data = np.random.rand(100).astype(np.float32)
y_data = x_data * 0.1 + 0.3

# Create placeholders for the input and output data
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

# Define the model's weight and bias
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))

# Define the linear model
model = W * X + b

# Define the loss function (mean squared error)
loss = tf.reduce_mean(tf.square(model - Y))

# Define the optimizer (gradient descent)
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.5)

# Define the training operation
train = optimizer.minimize(loss)

# Create a session to run the computation graph
with tf.Session() as sess:
    # Initialize the variables
    sess.run(tf.global_variables_initializer())

    # Training loop
    for step in range(201):
        _, current_loss, current_W, current_b = sess.run([train, loss, W, b], feed_dict={X: x_data, Y: y_data})
        if step % 20 == 0:
            print("Step:", step, " Loss:", current_loss, " W:", current_W, " b:", current_b)
# Out:
# WARNING:tensorflow:From /Applications/anaconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Step: 0  Loss: 0.021688087  W: [0.5532639]  b: [0.05502402]
# Step: 20  Loss: 0.0012863475  W: [0.21288648]  b: [0.23620163]
# Step: 40  Loss: 8.150283e-05  W: [0.1284151]  b: [0.28394106]
# Step: 60  Loss: 5.163994e-06  W: [0.10715248]  b: [0.29595774]
# Step: 80  Loss: 3.2718773e-07  W: [0.10180037]  b: [0.29898253]
# Step: 100  Loss: 2.0729862e-08  W: [0.10045318]  b: [0.2997439]
# Step: 120  Loss: 1.3131009e-09  W: [0.10011406]  b: [0.29993555]
# Step: 140  Loss: 8.31189e-11  W: [0.1000287]  b: [0.2999838]
# Step: 160  Loss: 5.272183e-12  W: [0.10000723]  b: [0.29999593]
# Step: 180  Loss: 3.302869e-13  W: [0.10000181]  b: [0.299999]
# ...

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# Generate some random data for the model
x_data = np.random.rand(100, 2).astype(np.float32)
y_data = np.random.randint(0, 2, (100, 1)).astype(np.float32)

# Create placeholders for the input and output data
X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32, [None, 1])

# Define the model's weights and biases
W1 = tf.Variable(tf.random_normal([2, 4]), name='weight1')
b1 = tf.Variable(tf.random_normal([4]), name='bias1')

W2 = tf.Variable(tf.random_normal([4, 1]), name='weight2')
b2 = tf.Variable(tf.random_normal([1]), name='bias2')

# Define the model's layers
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)
logits = tf.matmul(layer1, W2) + b2

# Define the loss function (cross-entropy)
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=Y))

# Define the optimizer (Adam)
optimizer = tf.train.AdamOptimizer(learning_rate=0.01)

# Define the training operation
train = optimizer.minimize(loss)

# Create a session to run the computation graph
with tf.Session() as sess:
    # Initialize the variables
    sess.run(tf.global_variables_initializer())

    # Training loop
    for step in range(2000000):
        _, current_loss = sess.run([train, loss], feed_dict={X: x_data, Y: y_data})
        if step % 200 == 0:
            print("Step:", step, " Loss:", current_loss)
# Out:
# Step: 0  Loss: 0.9225098
# Step: 200  Loss: 0.6884322
# Step: 400  Loss: 0.68642044
# Step: 600  Loss: 0.685323
# Step: 800  Loss: 0.68398774
# Step: 1000  Loss: 0.6822246
# Step: 1200  Loss: 0.67972183
# Step: 1400  Loss: 0.6760832
# Step: 1600  Loss: 0.6717947
# Step: 1800  Loss: 0.66825193
# Step: 2000  Loss: 0.6658595
# Step: 2200  Loss: 0.66404146
# Step: 2400  Loss: 0.6623089
# Step: 2600  Loss: 0.6604164
# Step: 2800  Loss: 0.65744734
# Step: 3000  Loss: 0.6507287
# Step: 3200  Loss: 0.6428335
# Step: 3400  Loss: 0.638129
# Step: 3600  Loss: 0.6364471
# Step: 3800  Loss: 0.63588065
# Step: 4000  Loss: 0.63536197
# Step: 4200  Loss: 0.63455087
# Step: 4400  Loss: 0.6333445
# Step: 4600  Loss: 0.6317739
# Step: 4800  Loss: 0.6299818
# Step: 5000  Loss: 0.6281661
# Step: 5200  Loss: 0.62666464
# Step: 5400  Loss: 0.62549776
# Step: 5600  Loss: 0.6245972
# Step: 5800  Loss: 0.62389517
# Step: 6000  Loss: 0.6233397
# Step: 6200  Loss: 0.62289405
# Step: 6400  Loss: 0.6225314
# ...

# %%
import keras
